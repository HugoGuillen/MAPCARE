# %% [markdown]
# # Minimal workflow
#
# - Make sure you have ollama running https://ollama.com/

# %%
import sys
import os
from os import path,listdir
import pandas as pd

pd.options.display.max_columns = 500
import warnings
warnings.filterwarnings('ignore')

import scripts
from scripts import translate_chop,clean_translations,embed_chop,parse_ops,translate_ops,embed_ops
from scripts import map_chop_ops

# %%
input_chop = 'data/chop.min.csv' #minimal file
output_chop = 'outputs/chop.min.csv'
output_chop_clean = 'outputs/chop.min.clean.csv'

output_embedding = 'outputs/embeddings_chop.min.parquet'
output_corpus = 'outputs/corpus_chop.min.txt'
persist_dir = 'outputs/db'

input_ops_xml = 'data/ops2023syst_claml_20221021.xml'
input_ops_abbv = 'data/OPS_ABBV.tsv'
output_ops_parsed = 'outputs/ops_parsed.csv'

ops_min = 'outputs/ops_parsed.min.csv'
ops_translated = 'outputs/ops_translated.min.csv'
ops_translated_clean = 'outputs/ops_translated.min.clean.csv'
output_embedding_ops = 'outputs/embeddings_ops.min.parquet'
output_corpus_ops = 'outputs/corpus_ops.min.txt'

# %% [markdown]
# ---
# # Process CHOP
# ## Translate

# %%
translate_chop.main(input_chop,output_chop)
# Out:
# Output:

# %%
pd.read_csv(output_chop)
# Out:
#     nbchar   zcode item type  \
# 0        1      C0         T
# 1        2     Z00         T
# 2        3   Z00.0         T
# 3        3   Z00.0         X
# 4        3   Z00.0         X
# ..     ...     ...       ...
# 94       4  Z00.39         B
# 95       3   Z00.4         T
# 96       3   Z00.4         N
# 97       3   Z00.4         S
# 98       3   Z00.4         S
#
#                                                  text codable  emitter  \
# 0   Massnahmen und Interventionen nicht anderswo K...     non      NaN
# 1   Massnahmen und Interventionen nicht anderswo k...     non      NaN
# 2                         Therapeutischer Ultraschall     non      NaN
# 3   Diagnostischer Ultraschall (nicht-invasiv) (88...     non      NaN
# 4       Intrakardiale Echokardiographie [IKE] (37.28)     non      NaN
# ..                                                ...     ...      ...
# 94             Computergesteuerte Chirurgie, n.n.bez.     non      NaN
# 95                     Adjunktiv vaskuläre Massnahmen     non      NaN
# 96  Die Kodes unter 00.4- sind Zusatzkodes. Sie bi...     non      NaN
# 97                 Endarteriektomie (38.10 - 38.18.-)     non      NaN
# 98  Jede Angioplastik oder Atherektomie (00.66.-, ...     non      NaN
#
#     status  modification date  indent level lateralite  \
# 0        0                NaN             1        NaN
# 1        0                NaN             2        NaN
# 2        0                NaN             3        NaN
# 3        0                NaN             3        NaN
# 4        0                NaN             3        NaN
# ..     ...                ...           ...        ...
# 94       0                NaN             4        NaN
# 95       0                NaN             3        NaN
# 96       0                NaN             3        NaN
# 97       0                NaN             3        NaN
# 98       0                NaN             3        NaN
#
#                                            clean_text  \
# 0   Massnahmen und Interventionen nicht anderswo K...
# 1   Massnahmen und Interventionen nicht anderswo k...
# 2                         Therapeutischer Ultraschall
# 3                        Diagnostischer Ultraschall
# 4              Intrakardiale Echokardiographie [IKE]
# ..                                                ...
# 94             Computergesteuerte Chirurgie, n.n.bez.
# 95                     Adjunktiv vaskuläre Massnahmen
# 96  Die Kodes unter 00.4- sind Zusatzkodes. Sie bi...
# 97                                  Endarteriektomie
# 98               Jede Angioplastik oder Atherektomie
#
#                                       translation_raw
# 0   Measures and Interventions Not Otherwise Class...
# 1   Measures and Interventions Not Otherwise Class...
# 2   Therapeutic Ultrasound|The application of ultr...
# 3   Diagnostic Ultrasound|A medical imaging techni...
# 4   Transthoracic echocardiography (TTE)| A non-in...
# ..                                                ...
# 94  Computer-Assisted Surgery, unspecified|A surgi...
# 95  Adjunctive Vascular Measures|Additional proced...
# 96  Codes under 00.4- are additional codes. They r...
# 97  Endarterectomy|A surgical procedure to remove ...
# 98  Every Angioplasty or Atherectomy |Angioplasty:...
#
# [99 rows x 12 columns]

# %% [markdown]
# ## Clean translation

# %%
clean_translations.main(output_chop,output_chop_clean)

# %% [markdown]
# ## Create embedding

# %%
embed_chop.main(output_chop_clean,output_embedding,output_corpus,persist_dir)
# Out:
# Embedding s/term: 0.04
# # Wrote outputs/embeddings_chop.min.parquet
# # Wrote outputs/corpus_chop.min.txt

# %% [markdown]
# ---
# # Process OPS

# %%
parse_ops.main(input_ops_xml,input_ops_abbv,output_ops_parsed)
# Out:
# # Wrote outputs/ops_parsed.csv

# %% [markdown]
# ## Create minimal file

# %%
# %%bash
# cat outputs/ops_parsed.csv | head -n 10 > outputs/ops_parsed.min.csv

# %% [markdown]
# ## Translate

# %%
translate_ops.main(ops_min,ops_translated)
# Out:
# Output:

# %% [markdown]
# ## Clean translation

# %%
clean_translations.main(ops_translated,ops_translated_clean)

# %% [markdown]
# ## Clean embedding

# %%
embed_ops.main(ops_translated_clean,output_embedding_ops,output_corpus_ops,persist_dir)
# Out:
# Embedding s/term: 0.21
# # Wrote outputs/embeddings_ops.min.parquet
# # Wrote outputs/corpus_ops.min.txt

# %% [markdown]
# ---
# # Map codebooks

# %%
output_mapping = 'outputs/ops_to_chop.csv'
map_chop_ops.main(output_embedding_ops,output_embedding,output_mapping,top_k=3)
df = pd.read_csv(output_mapping)
df
# Out:
#     A_df  B_df  similarity
# 0      0    87    0.864476
# 1      0    57    0.742353
# 2      0    59    0.722445
# 3      1    87    0.772411
# 4      1     3    0.697928
# 5      1    19    0.673854
# 6      2    87    0.767221
# 7      2     3    0.686891
# 8      2    19    0.666431
# 9      3    87    0.658893
# 10     3    57    0.639539
# 11     3     0    0.583696
# 12     4    87    0.742980
# 13     4     3    0.691600
# 14     4    59    0.669970
# 15     5    87    0.640941
# 16     5    62    0.625577
# 17     5    76    0.613289
# 18     6    87    0.668755
# 19     6    59    0.628850
# 20     6    62    0.612270
# 21     7    87    0.603462
# 22     7    48    0.585124
# 23     7    59    0.577287
# 24     8    87    0.608471
# 25     8    48    0.581061
# 26     8    59    0.580821

# %%
output_mapping = 'outputs/chop_to_ops.csv'
map_chop_ops.main(output_embedding,output_embedding_ops,output_mapping,top_k=3)
df = pd.read_csv(output_mapping)
df
# Out:
#      A_df  B_df  similarity
# 0       0     0    0.721629
# 1       0     4    0.617236
# 2       0     1    0.592342
# 3       1     0    0.646939
# 4       1     4    0.569626
# ..    ...   ...         ...
# 292    97     0    0.532027
# 293    97     6    0.525459
# 294    98     0    0.549949
# 295    98     4    0.520464
# 296    98     1    0.511518
#
# [297 rows x 3 columns]
